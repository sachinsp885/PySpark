# %% [markdown]
# # Drop

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

spark  = SparkSession.builder.appName("sort").getOrCreate()

df_read_csv = spark.read.format("csv")\
                        .option('inferSchema',True)\
                        .option('header',True)\
                        .load('C:/Git files/My git files/PySpark/files/products.csv')

# df_read_csv.printSchema()

# %%
df_read_csv.show(2)
# Out:
# +-----+--------------------+--------------------+--------------------+------------------+-----+--------+-----+-------------+-----------+-------+------------+-----------+
# |Index|                Name|         Description|               Brand|          Category|Price|Currency|Stock|          EAN|      Color|   Size|Availability|Internal ID|
# +-----+--------------------+--------------------+--------------------+------------------+-----+--------+-----+-------------+-----------+-------+------------+-----------+
# |    1|Compact Printer A...|Situation organiz...|Garner, Boyle and...|Books & Stationery|  265|     USD|  774|2091465262179|ForestGreen|  Large|   pre_order|         56|
# |    2|              Tablet|Discussion loss p...|         Mueller Inc|  Shoes & Footwear|  502|     USD|   81|5286196620740|      Black|8x10 in|    in_stock|         29|
# +-----+--------------------+--------------------+--------------------+------------------+-----+--------+-----+-------------+-----------+-------+------------+-----------+
# only showing top 2 rows

# %% [markdown]
# # Type 1 ->droping single column(drop paticular column)

# %%
df_read_csv.drop(col("Stock")).show(3)
# Out:
# +-----+--------------------+--------------------+--------------------+------------------+-----+--------+-------------+-----------+-------+------------+-----------+
# |Index|                Name|         Description|               Brand|          Category|Price|Currency|          EAN|      Color|   Size|Availability|Internal ID|
# +-----+--------------------+--------------------+--------------------+------------------+-----+--------+-------------+-----------+-------+------------+-----------+
# |    1|Compact Printer A...|Situation organiz...|Garner, Boyle and...|Books & Stationery|  265|     USD|2091465262179|ForestGreen|  Large|   pre_order|         56|
# |    2|              Tablet|Discussion loss p...|         Mueller Inc|  Shoes & Footwear|  502|     USD|5286196620740|      Black|8x10 in|    in_stock|         29|
# |    3|Smart Blender Cooker|   No situation per.|Lawson, Keller an...|Kitchen Appliances|  227|     USD|1282898648918|  SlateGray|     XS|    in_stock|         70|
# +-----+--------------------+--------------------+--------------------+------------------+-----+--------+-------------+-----------+-------+------------+-----------+
# only showing top 3 rows

# %% [markdown]
# # Type 2 ->droping multiple column

# %%
df_read_csv.drop('Name','Brand').show(4)
# Out:
# +-----+--------------------+------------------+-----+--------+-----+-------------+-----------+-------+------------+-----------+
# |Index|         Description|          Category|Price|Currency|Stock|          EAN|      Color|   Size|Availability|Internal ID|
# +-----+--------------------+------------------+-----+--------+-----+-------------+-----------+-------+------------+-----------+
# |    1|Situation organiz...|Books & Stationery|  265|     USD|  774|2091465262179|ForestGreen|  Large|   pre_order|         56|
# |    2|Discussion loss p...|  Shoes & Footwear|  502|     USD|   81|5286196620740|      Black|8x10 in|    in_stock|         29|
# |    3|   No situation per.|Kitchen Appliances|  227|     USD|  726|1282898648918|  SlateGray|     XS|    in_stock|         70|
# |    4|For force gas ene...|Kitchen Appliances|  121|     USD|  896|3879177514583|  PaleGreen|      L|discontinued|         31|
# +-----+--------------------+------------------+-----+--------+-----+-------------+-----------+-------+------------+-----------+
# only showing top 4 rows
