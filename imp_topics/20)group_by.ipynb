# %% [markdown]
# # Group By

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.appName("date").getOrCreate()

df = spark.read.format("csv")\
               .option("inferSchema",True)\
               .option('header',True)\
               .load("C:/Git files/My git files/PySpark/files/products.csv")

# %%
df.show()

# %% [markdown]
# # Type 1

# %%
df.groupBy("Category").agg(sum("Price").alias("sum_of_price")).show()

# %% [markdown]
# # Type 2

# %%
df.groupBy("Category","Brand").agg(sum("Price").alias("sum_of_price")).show()

# %% [markdown]
# # Type 3

# %%
df.groupBy("Category","Brand").agg(sum("Price").alias("sum_of_price"),mean("Price").alias("mean_of_price")).show()
# Out:
# +------------------+--------------------+------------+-------------+
# |          Category|               Brand|sum_of_price|mean_of_price|
# +------------------+--------------------+------------+-------------+
# |Clothing & Apparel|         Henry Group|        1716|        858.0|
# |       Team Sports|Malone, Jacobson ...|         731|        731.0|
# |         Furniture|       Larson-Spence|        1970|        985.0|
# | Fishing & Hunting|May, Hendrix and ...|         200|        100.0|
# |    Kids' Clothing|           Irwin LLC|           1|          1.0|
# |       Smartphones|            Bray LLC|        1058|        529.0|
# |        Automotive|       Contreras PLC|         279|        279.0|
# | Cleaning Supplies|Juarez, Powell an...|         101|        101.0|
# |          Skincare|Gallegos, Osborne...|        1328|        664.0|
# | Fitness Equipment|Huff, Cameron and...|         488|        488.0|
# |Kitchen Appliances|  Gallagher and Sons|         121|        121.0|
# ...
